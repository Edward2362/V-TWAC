# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/nathantran/opt/anaconda3/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nathantran/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/nathantran/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.5.0 in /Users/nathantran/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/nathantran/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.2.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pymongo
import pandas as pd
import numpy as np
import geopandas as gpd

sns.set(style="darkgrid")

# %%
client = pymongo.MongoClient("mongodb+srv://admin:PW0ysJYzBz2MTCCt@hd.4znyikg.mongodb.net/combination?retryWrites=true&w=majority")
db = client["combination"]

# %%
collection = db['traffic_weather_combination']
df = pd.DataFrame(list(collection.find()))
df.describe()
# Out:
#                mag1          mag2          mag3      app_temp       azimuth  \
# count  12775.000000  12775.000000  12775.000000  12775.000000  12775.000000
# mean       0.383327      0.656986      1.299256     25.039507    179.216908
# std        1.151641      1.901334      3.438686      5.826658     60.032581
# min        0.000000      0.000000      0.000000     17.000000     95.500000
# 25%        0.000000      0.000000      0.000000     20.500000    115.800000
# 50%        0.000000      0.000000      0.000000     24.400000    179.200000
# 75%        0.000000      0.000000      1.000000     27.100000    243.700000
# max       19.000000     29.000000     50.000000     40.300000    264.400000
#
#              clouds         dewpt           dhi           dni    elev_angle  \
# count  12775.000000  12775.000000  12775.000000  12775.000000  12775.000000
# mean      59.937613     20.218630     44.752877    364.026693     -7.439108
# std       36.479793      2.628407     50.332631    403.384094     43.340850
# min        0.000000     15.900000      0.000000      0.000000    -89.100000
# 25%       25.000000     18.000000      0.000000      0.000000    -46.000000
# 50%       60.000000     19.900000      0.000000      0.000000     -4.200000
# 75%      100.000000     22.900000    104.000000    845.000000     34.600000
# max      100.000000     26.000000    125.000000    956.000000     58.300000
#
#        ...           slp     snow     solar_rad          temp            uv  \
# count  ...  12775.000000  12775.0  12775.000000  12775.000000  12775.000000
# mean   ...   1014.220978      0.0    156.407750     23.735961      1.303100
# std    ...      2.824760      0.0    239.944342      4.392510      1.919231
# min    ...   1008.000000      0.0      0.000000     17.000000      0.000000
# 25%    ...   1012.000000      0.0      0.000000     20.000000      0.000000
# 50%    ...   1014.000000      0.0      0.000000     24.000000      0.000000
# 75%    ...   1016.000000      0.0    216.000000     26.000000      2.000000
# max    ...   1021.000000      0.0    871.000000     34.000000      8.900000
#
#                 vis      wind_dir  wind_gust_spd      wind_spd  weather_code
# count  12775.000000  12775.000000   12775.000000  12775.000000  12775.000000
# mean      13.054716    111.704501       2.686935      2.378651    777.559609
# std        3.331471     87.803895       1.799834      1.318393     78.624482
# min        3.000000      0.000000       0.000000      0.000000    500.000000
# 25%       10.000000     50.000000       1.000000      1.000000    801.000000
# 50%       16.000000    110.000000       2.200000      2.100000    803.000000
# 75%       16.000000    140.000000       3.300000      3.100000    804.000000
# max       16.000000    360.000000      11.200000      6.690000    804.000000
#
# [8 rows x 24 columns]

# %%
total_raw_document_count = collection.count_documents({})
def get_city_count(city):
    city_document_count = collection.count_documents({"city": city})
    print(city, city_document_count, "{perc:.2f}%".format(perc = city_document_count * 100 / total_raw_document_count))
    
cities = ["Ha Noi", "Hai Phong", "Da Nang", "Ho Chi Minh City", "Can Tho"]
for i in cities:
    get_city_count(i)
# Out:
# Ha Noi 4900 38.36%
# Hai Phong 1925 15.07%
# Da Nang 1225 9.59%
# Ho Chi Minh City 3500 27.40%
# Can Tho 1225 9.59%

# %%
selected_city_df = pd.DataFrame(list(collection.find({"$or": [{"city": "Ha Noi"}, {"city": "Ho Chi Minh City"}]})))

# %%
selected_city_df
# Out:
#                            _id      district                  dt  mag1  mag2  \
# 0     65a3f080c892a4d2cb4e1314       ba dinh 2024-01-06 16:00:00     0     0
# 1     65a3f080c892a4d2cb4e1315      cau giay 2024-01-06 16:00:00     2     3
# 2     65a3f080c892a4d2cb4e1316     chuong my 2024-01-06 16:00:00     1     0
# 3     65a3f080c892a4d2cb4e1317      dong anh 2024-01-06 16:00:00     1     1
# 4     65a3f080c892a4d2cb4e1318       dong da 2024-01-06 16:00:00     2     4
# ...                        ...           ...                 ...   ...   ...
# 8395  65a3f080c892a4d2cb4e4115        nha be 2024-01-11 11:00:00     0     0
# 8396  65a3f080c892a4d2cb4e4116     phu nhuan 2024-01-11 11:00:00     0     0
# 8397  65a3f080c892a4d2cb4e4117      tan binh 2024-01-11 11:00:00     0     0
# 8398  65a3f080c892a4d2cb4e4118       tan phu 2024-01-11 11:00:00     0     0
# 8399  65a3f080c892a4d2cb4e4119  tan phu dong 2024-01-11 11:00:00     0     0
#
#       mag3              city  app_temp  azimuth  clouds  ...  \
# 0        1            Ha Noi      21.5    261.1      70  ...
# 1        2            Ha Noi      21.5    261.1      70  ...
# 2        1            Ha Noi      21.5    261.1      70  ...
# 3        1            Ha Noi      21.5    261.1      70  ...
# 4        3            Ha Noi      21.5    261.1      70  ...
# ...    ...               ...       ...      ...     ...  ...
# 8395     0  Ho Chi Minh City      33.5    248.5       0  ...
# 8396     0  Ho Chi Minh City      33.5    248.5       0  ...
# 8397     0  Ho Chi Minh City      33.5    248.5       0  ...
# 8398     0  Ho Chi Minh City      33.5    248.5       0  ...
# 8399     0  Ho Chi Minh City      33.5    248.5       0  ...
#
#                       ts   uv  vis  wind_dir  wind_gust_spd  wind_spd  \
# 0    2024-01-06 16:00:00  0.0   10       140            1.0       1.0
# 1    2024-01-06 16:00:00  0.0   10       140            1.0       1.0
# 2    2024-01-06 16:00:00  0.0   10       140            1.0       1.0
# 3    2024-01-06 16:00:00  0.0   10       140            1.0       1.0
# 4    2024-01-06 16:00:00  0.0   10       140            1.0       1.0
# ...                  ...  ...  ...       ...            ...       ...
# 8395 2024-01-11 11:00:00  0.0   16       170            5.1       4.6
# 8396 2024-01-11 11:00:00  0.0   16       170            5.1       4.6
# 8397 2024-01-11 11:00:00  0.0   16       170            5.1       4.6
# 8398 2024-01-11 11:00:00  0.0   16       170            5.1       4.6
# 8399 2024-01-11 11:00:00  0.0   16       170            5.1       4.6
#
#               location weather_code  weather_icon  weather_description
# 0               Ha Noi          803          c03n        Broken clouds
# 1               Ha Noi          803          c03n        Broken clouds
# 2               Ha Noi          803          c03n        Broken clouds
# 3               Ha Noi          803          c03n        Broken clouds
# 4               Ha Noi          803          c03n        Broken clouds
# ...                ...          ...           ...                  ...
# 8395  Ho Chi Minh City          800          c01n            Clear Sky
# 8396  Ho Chi Minh City          800          c01n            Clear Sky
# 8397  Ho Chi Minh City          800          c01n            Clear Sky
# 8398  Ho Chi Minh City          800          c01n            Clear Sky
# 8399  Ho Chi Minh City          800          c01n            Clear Sky
#
# [8400 rows x 38 columns]

# %%
drop_cols = selected_city_df.drop(['_id', 'azimuth', 'dewpt', 'dhi', 'dni', 'elev_angle',
                                  'ghi', 'h_angle', 'pod', 'pres', 'revision_status', 'slp', 'snow', 'solar_rad',
                                  'ts','vis', 'wind_dir', 'wind_gust_spd'], axis=1)

# %%
drop_cols.columns
# Out:
# Index(['district', 'dt', 'mag1', 'mag2', 'mag3', 'city', 'app_temp', 'clouds',
#        'datetime', 'precip', 'rh', 'temp', 'timestamp_local', 'timestamp_utc',
#        'uv', 'wind_spd', 'location', 'weather_code', 'weather_icon',
#        'weather_description'],
#       dtype='object')

# %%
weather_status_unique = drop_cols['weather_description'].unique()
weather_status_unique
# Out:
# array(['Broken clouds', 'Overcast clouds', 'Clear Sky', 'Fog',
#        'Light rain', 'Scattered clouds', 'Few clouds'], dtype=object)

# %%
drop_cols['is_rain'] = drop_cols.weather_description.apply(lambda x: 'rain' in x.lower())
drop_cols['is_fog'] = drop_cols.weather_description.apply(lambda x: x == 'Fog')

# %%
drop_cols['timeframe'] = drop_cols.datetime.apply(lambda x: x.split(':')[-1])

# %%
for i in weather_status_unique:
    count = len(drop_cols[drop_cols.weather_description == i])
    print(i, "{perc:.2f}%".format(perc = count * 100/len(drop_cols)))
# Out:
# Broken clouds 15.43%
# Overcast clouds 41.05%
# Clear Sky 10.10%
# Fog 7.10%
# Light rain 7.67%
# Scattered clouds 14.14%
# Few clouds 4.52%

# %%
print(drop_cols['is_rain'].sum())
print(drop_cols['is_fog'].sum())
# Out:
# 644
# 596

# %%
incident_magnitudes = ['mag1', 'mag2', 'mag3']
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
for i, v in enumerate(incident_magnitudes):
    sns.histplot(x=v, data=drop_cols, ax=ax[i], multiple='stack', alpha=0.3, hue="is_fog", kde=True)
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
for i, v in enumerate(incident_magnitudes):
    sns.histplot(x=v, data=drop_cols, ax=ax[i], multiple='stack', alpha=0.3, hue="is_rain", kde=True)
plt.show()

# %%
corr_df = drop_cols[['precip', 'mag1', 'mag2', 'mag3', 'is_rain', 'is_fog']]

# %%
corr_matrix = corr_df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
drop_categorical_df = drop_cols.drop(['weather_description', 'weather_icon', 'weather_code', 'timestamp_local', 'timestamp_utc',
                                     'uv','wind_spd', 'location', 'city', 'dt', 'datetime'], axis=1)
drop_categorical_df
# Out:
#           district  mag1  mag2  mag3  app_temp  clouds  precip  rh  temp  \
# 0          ba dinh     0     0     1      21.5      70    0.00  90  21.0
# 1         cau giay     2     3     2      21.5      70    0.00  90  21.0
# 2        chuong my     1     0     1      21.5      70    0.00  90  21.0
# 3         dong anh     1     1     1      21.5      70    0.00  90  21.0
# 4          dong da     2     4     3      21.5      70    0.00  90  21.0
# ...            ...   ...   ...   ...       ...     ...     ...  ..   ...
# 8395        nha be     0     0     0      33.5       0    0.25  74  29.0
# 8396     phu nhuan     0     0     0      33.5       0    0.25  74  29.0
# 8397      tan binh     0     0     0      33.5       0    0.25  74  29.0
# 8398       tan phu     0     0     0      33.5       0    0.25  74  29.0
# 8399  tan phu dong     0     0     0      33.5       0    0.25  74  29.0
#
#       is_rain  is_fog timeframe
# 0       False   False        16
# 1       False   False        16
# 2       False   False        16
# 3       False   False        16
# 4       False   False        16
# ...       ...     ...       ...
# 8395    False   False        11
# 8396    False   False        11
# 8397    False   False        11
# 8398    False   False        11
# 8399    False   False        11
#
# [8400 rows x 12 columns]

# %%
targets = ['mag1', 'mag2', 'mag3']
target_mag = drop_categorical_df[targets]
training_df = drop_categorical_df.drop(targets, axis=1)
training_df
# Out:
#           district  app_temp  clouds  precip  rh  temp  is_rain  is_fog  \
# 0          ba dinh      21.5      70    0.00  90  21.0    False   False
# 1         cau giay      21.5      70    0.00  90  21.0    False   False
# 2        chuong my      21.5      70    0.00  90  21.0    False   False
# 3         dong anh      21.5      70    0.00  90  21.0    False   False
# 4          dong da      21.5      70    0.00  90  21.0    False   False
# ...            ...       ...     ...     ...  ..   ...      ...     ...
# 8395        nha be      33.5       0    0.25  74  29.0    False   False
# 8396     phu nhuan      33.5       0    0.25  74  29.0    False   False
# 8397      tan binh      33.5       0    0.25  74  29.0    False   False
# 8398       tan phu      33.5       0    0.25  74  29.0    False   False
# 8399  tan phu dong      33.5       0    0.25  74  29.0    False   False
#
#      timeframe
# 0           16
# 1           16
# 2           16
# 3           16
# 4           16
# ...        ...
# 8395        11
# 8396        11
# 8397        11
# 8398        11
# 8399        11
#
# [8400 rows x 9 columns]

# %%
# train_df_dummies = pd.get_dummies(training_df, drop_first=True)

# %% [markdown]
# ## Encoder

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False, dtype="int32").set_output(transform='pandas')
ohe.fit(training_df)
training_df_dummy = ohe.transform(training_df)

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(training_df_dummy, target_mag, test_size=0.25, random_state=42, shuffle=True)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

def error_metrics(y_true, y_hat):
    mae = mean_absolute_error(y_true, y_hat)
    r2 = r2_score(y_true, y_hat)
    print("======= ERROR METRICS =======")
    print("MAE: ", mae)
    print("R2: ", r2)
    # print("=============================")
    
    return mae, r2

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor

rf_model = MultiOutputRegressor(RandomForestRegressor(random_state=0, 
                                         # max_depth=max_depth,
                                         # max_features=max_features,
                                         n_jobs=-1,
                                         n_estimators=150))
rf_model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(n_estimators=150,
#                                                      n_jobs=-1,
#                                                      random_state=0))

# %%
train_result = rf_model.predict(X_train)
train_res_df = pd.DataFrame(train_result)
error_metrics(y_train.mag1, train_res_df[0])
error_metrics(y_train.mag2, train_res_df[1])
error_metrics(y_train.mag3, train_res_df[2])
# Out:
# ======= ERROR METRICS =======
# MAE:  0.18835985638699929
# R2:  0.8946104620054285
# ======= ERROR METRICS =======
# MAE:  0.30652254220206604
# R2:  0.9045730816468761
# ======= ERROR METRICS =======
# MAE:  0.5326582640463593
# R2:  0.9118169803932361
# (0.5326582640463593, 0.9118169803932361)

# %%
test_result = rf_model.predict(X_test)
test_res_df = pd.DataFrame(test_result)

# %%
error_metrics(y_test.mag1, test_res_df[0])
error_metrics(y_test.mag2, test_res_df[1])
error_metrics(y_test.mag3, test_res_df[2])
# Out:
# ======= ERROR METRICS =======
# MAE:  0.4680912585034014
# R2:  0.2807322959867591
# ======= ERROR METRICS =======
# MAE:  0.8075139871504158
# R2:  0.30376880334206935
# ======= ERROR METRICS =======
# MAE:  1.489217520786092
# R2:  0.2918262837284058
# (1.489217520786092, 0.2918262837284058)

# %%
from sklearn.neural_network import MLPRegressor

nn_model = MultiOutputRegressor(MLPRegressor(random_state=0, 
                                             hidden_layer_sizes=(32, 32, 128), 
                                             alpha=1e-4,
                                             early_stopping=True,
                                             validation_fraction=0.05,
                                             shuffle=True
                                             ))
nn_model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=MLPRegressor(early_stopping=True,
#                                             hidden_layer_sizes=(32, 32, 128),
#                                             random_state=0,
#                                             validation_fraction=0.05))

# %%
nn_train_result = nn_model.predict(X_train)
nn_train_res_df = pd.DataFrame(nn_train_result)
error_metrics(y_train.mag1, nn_train_res_df[0])
error_metrics(y_train.mag2, nn_train_res_df[1])
error_metrics(y_train.mag3, nn_train_res_df[2])
# Out:
# ======= ERROR METRICS =======
# MAE:  0.29343978563844614
# R2:  0.7988502621032139
# ======= ERROR METRICS =======
# MAE:  0.3881023815811077
# R2:  0.8922151893743062
# ======= ERROR METRICS =======
# MAE:  0.7988804544166465
# R2:  0.8770848675750268
# (0.7988804544166465, 0.8770848675750268)

# %%
nn_test_result = nn_model.predict(X_test)
nn_test_res_df = pd.DataFrame(nn_test_result)

# %%
error_metrics(y_test.mag1, nn_test_res_df[0])
error_metrics(y_test.mag2, nn_test_res_df[1])
error_metrics(y_test.mag3, nn_test_res_df[2])
# Out:
# ======= ERROR METRICS =======
# MAE:  0.3932769996294748
# R2:  0.5188559642123634
# ======= ERROR METRICS =======
# MAE:  0.6192414126857606
# R2:  0.6104569052922597
# ======= ERROR METRICS =======
# MAE:  1.0732443032291696
# R2:  0.7030051821614751
# (1.0732443032291696, 0.7030051821614751)

# %%
error_metrics(y_test.mag1, np.round(nn_test_res_df[0]))
error_metrics(y_test.mag2, np.round(nn_test_res_df[1]))
error_metrics(y_test.mag3, np.round(nn_test_res_df[2]))
# Out:
# ======= ERROR METRICS =======
# MAE:  0.34523809523809523
# R2:  0.500733934196594
# ======= ERROR METRICS =======
# MAE:  0.5733333333333334
# R2:  0.6055944346757298
# ======= ERROR METRICS =======
# MAE:  1.0223809523809524
# R2:  0.700505971745673
# (1.0223809523809524, 0.700505971745673)

# %%
# def plot_nn_learning(model):
#     fig, ax = plt.subplots(2, 3, figsize=(15, 7))
#     # ax = ax.flatten()
#     for i, v in enumerate(model.estimators_):
#         ax[0, i].set_title(f"mag {i+1} val score")
#         sns.lineplot(data=model.estimators_[i].validation_scores_, ax=ax[0, i])
#         ax[1, i].set_title(f"mag {i+1} loss")
#         sns.lineplot(data=model.estimators_[i].loss_curve_, ax=ax[1, i], color="orange")

# plot_nn_learning(nn_model)

# %%
fig, ax = plt.subplots(figsize=(15, 6))

sns.histplot(data=np.round(nn_test_res_df[2]), alpha=0.3, kde=True, color="orange", ax=ax)
sns.histplot(data=y_test.mag3, alpha=0.3, kde=True, color="navy", ax=ax)
ax.set_xlim(-.5, 10)
# Out:
# (-0.5, 10.0)

# %%
muon_tam = [
  {
    "app_temp": 20.5,
    "clouds": 49,
    "datetime": "00",
    "precip": 0,
    "rh": 84,
    "temp": 20.2,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 21.6,
    "clouds": 49,
    "datetime": "01",
    "precip": 0,
    "rh": 79,
    "temp": 21.3,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 22.6,
    "clouds": 49,
    "datetime": "02",
    "precip": 0,
    "rh": 75,
    "temp": 22.4,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 23.8,
    "clouds": 49,
    "datetime": "03",
    "precip": 0,
    "rh": 70,
    "temp": 23.6,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 24.8,
    "clouds": 55,
    "datetime": "04",
    "precip": 0,
    "rh": 67,
    "temp": 24.5,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 25.6,
    "clouds": 60,
    "datetime": "05",
    "precip": 0,
    "rh": 63,
    "temp": 25.4,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 26.7,
    "clouds": 65,
    "datetime": "06",
    "precip": 0,
    "rh": 60,
    "temp": 26.4,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 26.6,
    "clouds": 61,
    "datetime": "07",
    "precip": 0,
    "rh": 59,
    "temp": 26.4,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 26.6,
    "clouds": 57,
    "datetime": "08",
    "precip": 0,
    "rh": 59,
    "temp": 26.4,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 26.7,
    "clouds": 52,
    "datetime": "09",
    "precip": 0,
    "rh": 58,
    "temp": 26.5,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 26.2,
    "clouds": 53,
    "datetime": "10",
    "precip": 3.5,
    "rh": 59,
    "temp": 26,
    "is_rain": True,
    "is_fog": False
  },
  {
    "app_temp": 25.7,
    "clouds": 53,
    "datetime": "11",
    "precip": 0,
    "rh": 61,
    "temp": 25.5,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 25.2,
    "clouds": 53,
    "datetime": "12",
    "precip": 0,
    "rh": 62,
    "temp": 25,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 24,
    "clouds": 57,
    "datetime": "13",
    "precip": 0,
    "rh": 65,
    "temp": 23.9,
    "is_rain": False,
    "is_fog": False
  },
  {
    "app_temp": 22.8,
    "clouds": 61,
    "datetime": "14",
    "precip": 0,
    "rh": 69,
    "temp": 22.7,
    "is_rain": False,
    "is_fog": False
  }
]

# %%
muon_tam_dict = {
"district": [],
"app_temp": [],
"clouds": [],
"precip": [],
"rh": [],
"temp": [],
"is_rain": [],
"is_fog": [],
"timeframe": [],
}

# %%
for i in muon_tam:
    muon_tam_dict["district"].append("cau giay")
    muon_tam_dict["app_temp"].append(i['app_temp'])
    muon_tam_dict["clouds"].append(i['clouds'])
    muon_tam_dict["precip"].append(i['precip'])
    muon_tam_dict["rh"].append(i['rh'])
    muon_tam_dict["temp"].append(i['temp'])
    muon_tam_dict["is_rain"].append(i['is_rain'])
    muon_tam_dict["is_fog"].append(i['is_fog'])
    muon_tam_dict["timeframe"].append(i['datetime'])

# %%
forecast_df = pd.DataFrame.from_dict(muon_tam_dict)
forecast_df
# Out:
#     district  app_temp  clouds  precip  rh  temp  is_rain  is_fog timeframe
# 0   cau giay      20.5      49     0.0  84  20.2    False   False        00
# 1   cau giay      21.6      49     0.0  79  21.3    False   False        01
# 2   cau giay      22.6      49     0.0  75  22.4    False   False        02
# 3   cau giay      23.8      49     0.0  70  23.6    False   False        03
# 4   cau giay      24.8      55     0.0  67  24.5    False   False        04
# 5   cau giay      25.6      60     0.0  63  25.4    False   False        05
# 6   cau giay      26.7      65     0.0  60  26.4    False   False        06
# 7   cau giay      26.6      61     0.0  59  26.4    False   False        07
# 8   cau giay      26.6      57     0.0  59  26.4    False   False        08
# 9   cau giay      26.7      52     0.0  58  26.5    False   False        09
# 10  cau giay      26.2      53     3.5  59  26.0     True   False        10
# 11  cau giay      25.7      53     0.0  61  25.5    False   False        11
# 12  cau giay      25.2      53     0.0  62  25.0    False   False        12
# 13  cau giay      24.0      57     0.0  65  23.9    False   False        13
# 14  cau giay      22.8      61     0.0  69  22.7    False   False        14

# %%
forecast_encoded_df = ohe.transform(forecast_df)
forecast_result = nn_model.predict(forecast_encoded_df)
forecast_result_df = pd.DataFrame(forecast_result)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

for k in range(3):
    sns.barplot(x = forecast_df.timeframe,
            y = forecast_result_df[k], ax=axes[k])
    sns.lineplot(x = forecast_df.timeframe,
            y = forecast_df.precip, color='navy', marker='o', ax=axes[k])
    
    axes[k].set_title(f"Magnitude of delay: {k+1}")
    axes[k].set_ylim(-1, max(forecast_result_df[[0 ,1 ,2]].max()) + 1)
plt.show()

# %%
test_extract = drop_cols.copy().drop(['weather_description', 'weather_icon', 'weather_code', 'timestamp_local', 'timestamp_utc',
                                     'uv','wind_spd', 'location', 'city', 'dt',], axis=1)
test_extract["date"] = test_extract.datetime.apply(lambda x: x.split(":")[0])
test_extract["date"] = test_extract["date"].apply(lambda x: int(x.split("-")[-1]))

test_extract = test_extract[test_extract.district == "cau giay"]
test_extract = test_extract[test_extract.date == 10]
test_extract = test_extract.drop(['date', 'datetime'], axis=1)
test_extract = test_extract.drop(targets, axis=1)

# %%
extract_encoded_df = ohe.transform(test_extract)
extract_result = nn_model.predict(extract_encoded_df)
extract_result_df = pd.concat([test_extract.reset_index(drop=True), pd.DataFrame(extract_result)], axis=1)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))

for k in range(3):
    sns.barplot(x = extract_result_df.timeframe,
            y = extract_result_df[k], ax=axes[k])
    sns.lineplot(x = extract_result_df.timeframe,
            y = extract_result_df.precip, color='navy', marker='o', ax=axes[k])
    
    axes[k].set_title(f"Magnitude of delay: {k+1}")
    axes[k].set_ylim(-1, max(extract_result_df[[0 ,1 ,2]].max()) + 1)
plt.show()
